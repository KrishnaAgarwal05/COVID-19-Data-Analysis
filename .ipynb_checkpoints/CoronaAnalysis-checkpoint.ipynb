# %% [markdown]
# # CoronaVirus Data Analysis
#
# To understand the trend of Virus circulation at Country, State and City level I have created this jupyter notebook.
# The data used is taken from Johns Hopkins Universities open source on github which is in-accordance with WHO and CDC.
#
# The data can be visualized at country, state and city level. In order to use it you can pass the below parameters in the function calls:
#
# country
#
# state
#
# city
#
# Note : The values that can be passed in the above parameters can be of string or list type only.

# %% [markdown]
# # Importing Required Packages of Python

# %%
import sys
sys.path.append('./')
from src import ReadData as rd
from src import maps
from src import DataPlotting as dap
from src import DataFormatting as daf

# %% [markdown]
# # Importing Data from Daily Report Files

# %%
COVID_DATA_df = rd.importfiles()
US_COVID_DATA_df = rd.cities_usa_importfiles()

# %% [markdown]
# # Plotting Information of Countries/States/Cities with Highest CoronaVirus Cases As of Today

# %%
maps.world_mapping(COVID_DATA_df,'Confirmed')

# %%
dap.country_wise_count_plot(COVID_DATA_df)

# %%
maps.mapping_usa(US_COVID_DATA_df,'Confirmed')

# %% [markdown]
# # Plotting The Timeline of CoronaVirus Across The Globe

# %%
dap.plot_timeline_total(COVID_DATA_df)
dap.plot_timeline_total(COVID_DATA_df, country='US')

# %% [markdown]
# # Plotting Timeline of Countries/States/Cities with Highest CoronaVirus Cases

# %% [markdown]
# # Cases in Top 5 Impacted Countries

# %%
dap.plot_timeline_countrywise_CONFIRMED(COVID_DATA_df)
dap.plot_timeline_countrywise_RECOVERED(COVID_DATA_df)
dap.plot_timeline_countrywise_DEATHS(COVID_DATA_df)

# %% [markdown]
# # Cases in Selected Countries

# %%
dap.plot_timeline_countrywise_CONFIRMED(COVID_DATA_df, country='US')
dap.plot_timeline_countrywise_RECOVERED(COVID_DATA_df, country='US')
dap.plot_timeline_countrywise_DEATHS(COVID_DATA_df, country='US')

# %% [markdown]
# # Viewing the Data of Top 5 Countries Impacted by CoronaVirus Cases

# %%
df = daf.country_wise_count(COVID_DATA_df)
df.head(10)
# Out:
#      Country/Region  Confirmed   Deaths  Recovered
# 168              US   215417.0   5116.0     8566.0
# 84            Italy   110574.0  13155.0    16847.0
# 153           Spain   104118.0   9387.0    22647.0
# 36            China    82381.0   3316.0    76409.0
# 65          Germany    77981.0    931.0    18700.0
# 61           France    57763.0   4043.0    11055.0
# 80             Iran    47593.0   3036.0    15473.0
# 172  United Kingdom    29865.0   2357.0      179.0
# 158     Switzerland    17768.0    488.0     2967.0
# 167          Turkey    15679.0    277.0      333.0

# %% [markdown]
# # Viewing the Data of CoronaVirus Cases Across the Globe For Past 5 Days

# %%
df = daf.timeline_total(COVID_DATA_df)
df.tail()
# Out:
#    Last Update  Confirmed  Recovered   Deaths
# 66  03-28-2020   660706.0   139415.0  30652.0
# 67  03-29-2020   720117.0   149082.0  33925.0
# 68  03-30-2020   782365.0   164566.0  37582.0
# 69  03-31-2020   857487.0   178034.0  42107.0
# 70  04-01-2020   935817.0   193700.0  47208.0

# %% [markdown]
# # Plotting the Daily New Cases of CoronaVirus for Countries/States/Cities

# %% [markdown]
# # New Cases in Top 5 Impacted Countries

# %%
dap.plot_timeline__new_cases_countrywise_CONFIRMED(COVID_DATA_df)
dap.plot_timeline__new_cases_countrywise_RECOVERED(COVID_DATA_df)
dap.plot_timeline__new_cases_countrywise_DEATHS(COVID_DATA_df)

# %% [markdown]
# # New Cases in Selected Countries

# %%
dap.plot_timeline__new_cases_countrywise_CONFIRMED(COVID_DATA_df,country=['India','Japan'])
dap.plot_timeline__new_cases_countrywise_DEATHS(COVID_DATA_df,country=['India','Japan'])

# %%
def import_population():
    population_df = pd.read_csv('./WorldPopulation/data.csv')
    population_df = population_df[['name','pop2020']]
    population_df.columns = population_df.columns.str.replace('pop2020', 'Population')
    population_df['Population'] = population_df['Population']*1000
    pd.set_option('display.float_format', lambda x: '%.0f' % x)
    
    population_df['name'] = population_df['name'].replace('United States','US')
    return population_df
